# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df_1 = pd.read_csv("data/acsee_results_2023.csv")
df_2 = pd.read_csv("data/acsee_results_2024.csv")

# %%
df_1 = df_1[ ~df_1.gpa.isnull() ]
df_1.rename({'gpa':'prev_gpa'},axis=1,inplace=True)

# %%
df_2 = df_2[ ~df_2.gpa.isnull() ]

# %%
df_3 = pd.read_csv("project_school_performance_data(2023).csv")

# %%
df_3 = df_3[ ~df_3.GPA.isnull() ]
df_3.rename({'SCHOOL':'school_code','GPA':'prev_gpa','NUMBER OF CANDIDATES':'prev_enroll','SAT FOR EXAM':'prev_sat'},axis=1,inplace=True)

# %%
df = pd.concat([df_3.set_index('school_code'),df_2.set_index('school_code')], axis=1)

# %%
df.isnull().sum()
# Out:
# prev_enroll                 71
# prev_sat                    71
# SCHOOL OWNERSHIP           757
# SCHOOL CATEGORY            757
# SCHOOL TYPE                762
# COMBINATIONS CATEGORY      769
# ACADEMIC LEVEL CATEGORY    769
# TOTAL PASSED CANDIDATES     71
# prev_gpa                    71
# school_name                 19
# is_private_center           19
# region                      19
# gpa                         19
# grade                      948
# passed_candidates           19
# regist                      19
# absent                      19
# sat                         19
# withheld                    19
# no-ca                       19
# clean                       19
# div_i                       19
# div_ii                      19
# div_iii                     19
# div_iv                      19
# div_0                       19
# STUDENTS                   754
# TEACHERS                   754
# STUDENT-TEACHER RATIO      754
# dtype: int64

# %%
df.columns
# Out:
# Index(['prev_enroll', 'prev_sat', 'SCHOOL OWNERSHIP', 'SCHOOL CATEGORY',
#        'SCHOOL TYPE', 'COMBINATIONS CATEGORY', 'ACADEMIC LEVEL CATEGORY',
#        'TOTAL PASSED CANDIDATES', 'prev_gpa', 'school_name',
#        'is_private_center', 'region', 'gpa', 'grade', 'passed_candidates',
#        'regist', 'absent', 'sat', 'withheld', 'no-ca', 'clean', 'div_i',
#        'div_ii', 'div_iii', 'div_iv', 'div_0', 'STUDENTS', 'TEACHERS',
#        'STUDENT-TEACHER RATIO'],
#       dtype='object')

# %%
df = df[ ~(df.gpa.isnull() | df.prev_gpa.isnull())].drop(columns=['school_name','prev_enroll','regist','TOTAL PASSED CANDIDATES','no-ca','withheld', 'clean','absent','passed_candidates','is_private_center', 'region','grade','div_i', 'div_ii', 'div_iii', 'div_iv', 'div_0']).copy()

# %%
df.columns
# Out:
# Index(['prev_sat', 'SCHOOL OWNERSHIP', 'SCHOOL CATEGORY', 'SCHOOL TYPE',
#        'COMBINATIONS CATEGORY', 'ACADEMIC LEVEL CATEGORY', 'prev_gpa', 'gpa',
#        'sat', 'STUDENTS', 'TEACHERS', 'STUDENT-TEACHER RATIO'],
#       dtype='object')

# %%
df
# Out:
#              prev_sat SCHOOL OWNERSHIP SCHOOL CATEGORY       SCHOOL TYPE  \
# school_code
# s0101           196.0       GOVERNMENT       BOYS ONLY  DAY AND BOARDING
# s0103           467.0              NaN             NaN               NaN
# s0104           131.0              NaN             NaN               NaN
# s0105           169.0              NaN             NaN               NaN
# s0106             8.0              NaN             NaN               NaN
# ...               ...              ...             ...               ...
# s6064           146.0              NaN             NaN               NaN
# s6136            15.0              NaN             NaN               NaN
# s6209            56.0              NaN             NaN               NaN
# s6247           114.0              NaN             NaN               NaN
# s6249            48.0              NaN             NaN               NaN
#
#             COMBINATIONS CATEGORY ACADEMIC LEVEL CATEGORY prev_gpa     gpa  \
# school_code
# s0101                       MIXED             COMBINED OA   2.7577  3.0222
# s0103                         NaN                     NaN   2.7099  2.8265
# s0104                         NaN                     NaN   2.7455  2.4112
# s0105                         NaN                     NaN   2.1617  2.3932
# s0106                         NaN                     NaN   2.7917  2.5000
# ...                           ...                     ...      ...     ...
# s6064                         NaN                     NaN   2.8938  3.2005
# s6136                         NaN                     NaN   3.4778  2.4889
# s6209                         NaN                     NaN   2.8244  2.3827
# s6247                         NaN                     NaN   2.3480  2.2991
# s6249                         NaN                     NaN   2.5069  1.9432
#
#                sat STUDENTS TEACHERS STUDENT-TEACHER RATIO
# school_code
# s0101        158.0     1515       80                  19:1
# s0103        389.0      NaN      NaN                   NaN
# s0104        122.0      NaN      NaN                   NaN
# s0105        220.0      NaN      NaN                   NaN
# s0106          4.0      NaN      NaN                   NaN
# ...            ...      ...      ...                   ...
# s6064        217.0      NaN      NaN                   NaN
# s6136         15.0      NaN      NaN                   NaN
# s6209         54.0      NaN      NaN                   NaN
# s6247         39.0      NaN      NaN                   NaN
# s6249         88.0      NaN      NaN                   NaN
#
# [858 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# prev_sat                     0
# SCHOOL OWNERSHIP           675
# SCHOOL CATEGORY            675
# SCHOOL TYPE                680
# COMBINATIONS CATEGORY      686
# ACADEMIC LEVEL CATEGORY    686
# prev_gpa                     0
# gpa                          0
# sat                          0
# STUDENTS                   675
# TEACHERS                   675
# STUDENT-TEACHER RATIO      675
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 858 entries, s0101 to s6249
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   prev_sat                 858 non-null    float64
#  1   SCHOOL OWNERSHIP         183 non-null    object
#  2   SCHOOL CATEGORY          183 non-null    object
#  3   SCHOOL TYPE              178 non-null    object
#  4   COMBINATIONS CATEGORY    172 non-null    object
#  5   ACADEMIC LEVEL CATEGORY  172 non-null    object
#  6   prev_gpa                 858 non-null    object
#  7   gpa                      858 non-null    float64
#  8   sat                      858 non-null    float64
#  9   STUDENTS                 183 non-null    object
#  10  TEACHERS                 183 non-null    object
#  11  STUDENT-TEACHER RATIO    183 non-null    object
# dtypes: float64(3), object(9)
# memory usage: 87.1+ KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Convert to integers
df['STUDENTS'] = pd.to_numeric(df['STUDENTS'], errors='coerce')
df['TEACHERS'] = pd.to_numeric(df['TEACHERS'], errors='coerce')
# Or convert to floats
df['prev_gpa'] = pd.to_numeric(df['prev_gpa'], errors='coerce')

df['student_teacher_ratio'] = (
    df['STUDENT-TEACHER RATIO']
    .str.split(':')
    .str[0]
    .apply(lambda x: x.strip() if isinstance(x, str) else x)
)

# Convert to float, coercing non-numeric values (e.g., 'Not Available') to NaN
# df['student_teacher_ratio'] = pd.to_numeric(df['student_teacher_ratio'], errors='coerce')
df['student_teacher_ratio'] = df['STUDENTS'] / df['TEACHERS']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 858 entries, s0101 to s6249
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   prev_sat                 858 non-null    float64
#  1   SCHOOL OWNERSHIP         183 non-null    object
#  2   SCHOOL CATEGORY          183 non-null    object
#  3   SCHOOL TYPE              178 non-null    object
#  4   COMBINATIONS CATEGORY    172 non-null    object
#  5   ACADEMIC LEVEL CATEGORY  172 non-null    object
#  6   prev_gpa                 857 non-null    float64
#  7   gpa                      858 non-null    float64
#  8   sat                      858 non-null    float64
#  9   STUDENTS                 178 non-null    float64
#  10  TEACHERS                 178 non-null    float64
#  11  STUDENT-TEACHER RATIO    183 non-null    object
#  12  student_teacher_ratio    178 non-null    float64
# dtypes: float64(7), object(6)
# memory usage: 93.8+ KB

# %%
def swap_students_teachers_if_ratio_zero(df):
    """
    Swap values in 'STUDENTS' and 'TEACHERS' columns 
    if 'student_teacher_ratio' is 0 or less.
    """
    # Ensure the column exists and is numeric
    df = df.copy()
    
    # Check for NaN or invalid values
    condition = (df['student_teacher_ratio'].fillna(0) <= 1)

    # Use .values to swap correctly
    df.loc[condition, ['STUDENTS', 'TEACHERS']] = df.loc[condition, ['TEACHERS', 'STUDENTS']].values

    return df

# %%
df = swap_students_teachers_if_ratio_zero(df)

# %%
df.describe()
# Out:
#          prev_sat    prev_gpa         gpa         sat     STUDENTS  \
# count  858.000000  857.000000  858.000000  858.000000   178.000000
# mean   111.826340    2.636597    2.505567  117.195804   661.123596
# std    106.742349    0.451234    0.441079  107.517609   433.651252
# min      1.000000    1.289100    1.335700    1.000000   144.000000
# 25%     37.000000    2.357500    2.229775   40.250000   400.000000
# 50%     81.000000    2.644100    2.473650   87.000000   545.000000
# 75%    145.000000    2.893800    2.750000  153.000000   800.000000
# max    676.000000    4.566500    4.460000  645.000000  3500.000000
#
#          TEACHERS  student_teacher_ratio
# count  178.000000             178.000000
# mean    40.022472              16.030341
# std     19.455572               5.813678
# min     10.000000               0.028302
# 25%     30.000000              12.425000
# 50%     35.000000              14.928571
# 75%     50.000000              19.217134
# max    115.000000              41.860465

# %%
df['student_teacher_ratio'] = df['STUDENTS'] / df['TEACHERS']

# %%
df.describe()
# Out:
#          prev_sat    prev_gpa         gpa         sat     STUDENTS  \
# count  858.000000  857.000000  858.000000  858.000000   178.000000
# mean   111.826340    2.636597    2.505567  117.195804   661.123596
# std    106.742349    0.451234    0.441079  107.517609   433.651252
# min      1.000000    1.289100    1.335700    1.000000   144.000000
# 25%     37.000000    2.357500    2.229775   40.250000   400.000000
# 50%     81.000000    2.644100    2.473650   87.000000   545.000000
# 75%    145.000000    2.893800    2.750000  153.000000   800.000000
# max    676.000000    4.566500    4.460000  645.000000  3500.000000
#
#          TEACHERS  student_teacher_ratio
# count  178.000000             178.000000
# mean    40.022472              16.451816
# std     19.455572               5.631726
# min     10.000000               8.947368
# 25%     30.000000              12.500000
# 50%     35.000000              15.058140
# 75%     50.000000              19.933333
# max    115.000000              41.860465

# %%
def studying_hours(x):
    """
    Returns studying hours with linear relationship plus normal noise.
    
    Args:
        x: Input value gpa
    
    Returns:
        Hours of studying (8*x + random noise from N(0,2))
    """
    noise = np.random.normal(loc=0, scale=4)
    return (8 * x + noise) * 5

# %%
def number_of_books(x):
    """
    Returns number of books using the formula: 10 * x + N(0,5)
    
    Returns:
        Number of books (30.222 + random noise from N(0,5))
    """
    noise = np.random.normal(loc=0, scale=100)
    return int(50 + 200 * x + noise)

# %%
def teacher_qualification(gpa):
    if gpa < 2.0:
        probs = [0.70, 0.25, 0.05]  # Basic, Intermediate, Advanced
    elif gpa <= 3.0:
        probs = [0.10, 0.70, 0.20]
    else:
        probs = [0.05, 0.25, 0.70]
    return np.random.choice(['Basic', 'Intermediate', 'Advanced'], p=probs)
# teacher_qualification = [assign_teacher_qualification(gpa) for gpa in gpa_data]

# %%
df['studying_hours'] = df.gpa.apply(studying_hours)
df['number_of_books'] = df.gpa.apply(number_of_books)
df['teacher_qualification'] = df.gpa.apply(teacher_qualification)

# %%
df
# Out:
#              prev_sat SCHOOL OWNERSHIP SCHOOL CATEGORY       SCHOOL TYPE  \
# school_code
# s0101           196.0       GOVERNMENT       BOYS ONLY  DAY AND BOARDING
# s0103           467.0              NaN             NaN               NaN
# s0104           131.0              NaN             NaN               NaN
# s0105           169.0              NaN             NaN               NaN
# s0106             8.0              NaN             NaN               NaN
# ...               ...              ...             ...               ...
# s6064           146.0              NaN             NaN               NaN
# s6136            15.0              NaN             NaN               NaN
# s6209            56.0              NaN             NaN               NaN
# s6247           114.0              NaN             NaN               NaN
# s6249            48.0              NaN             NaN               NaN
#
#             COMBINATIONS CATEGORY ACADEMIC LEVEL CATEGORY  prev_gpa     gpa  \
# school_code
# s0101                       MIXED             COMBINED OA    2.7577  3.0222
# s0103                         NaN                     NaN    2.7099  2.8265
# s0104                         NaN                     NaN    2.7455  2.4112
# s0105                         NaN                     NaN    2.1617  2.3932
# s0106                         NaN                     NaN    2.7917  2.5000
# ...                           ...                     ...       ...     ...
# s6064                         NaN                     NaN    2.8938  3.2005
# s6136                         NaN                     NaN    3.4778  2.4889
# s6209                         NaN                     NaN    2.8244  2.3827
# s6247                         NaN                     NaN    2.3480  2.2991
# s6249                         NaN                     NaN    2.5069  1.9432
#
#                sat  STUDENTS  TEACHERS STUDENT-TEACHER RATIO  \
# school_code
# s0101        158.0    1515.0      80.0                  19:1
# s0103        389.0       NaN       NaN                   NaN
# s0104        122.0       NaN       NaN                   NaN
# s0105        220.0       NaN       NaN                   NaN
# s0106          4.0       NaN       NaN                   NaN
# ...            ...       ...       ...                   ...
# s6064        217.0       NaN       NaN                   NaN
# s6136         15.0       NaN       NaN                   NaN
# s6209         54.0       NaN       NaN                   NaN
# s6247         39.0       NaN       NaN                   NaN
# s6249         88.0       NaN       NaN                   NaN
#
#              student_teacher_ratio  studying_hours  number_of_books  \
# school_code
# s0101                      18.9375       97.132930              660
# s0103                          NaN      108.672330              641
# s0104                          NaN      107.607907              394
# s0105                          NaN       95.476595              467
# s0106                          NaN      102.004858              633
# ...                            ...             ...              ...
# s6064                          NaN      138.150922              727
# s6136                          NaN       81.084489              560
# s6209                          NaN      104.781522              500
# s6247                          NaN       80.561869              699
# s6249                          NaN       59.011366              411
#
#             teacher_qualification
# school_code
# s0101                    Advanced
# s0103                Intermediate
# s0104                Intermediate
# s0105                Intermediate
# s0106                Intermediate
# ...                           ...
# s6064                    Advanced
# s6136                       Basic
# s6209                Intermediate
# s6247                Intermediate
# s6249                       Basic
#
# [858 rows x 16 columns]

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
df
# Out:
#              prev_sat SCHOOL OWNERSHIP SCHOOL CATEGORY       SCHOOL TYPE  \
# school_code
# s0101           196.0       GOVERNMENT       BOYS ONLY  DAY AND BOARDING
# s0103           467.0              NaN             NaN               NaN
# s0104           131.0              NaN             NaN               NaN
# s0105           169.0              NaN             NaN               NaN
# s0106             8.0              NaN             NaN               NaN
# ...               ...              ...             ...               ...
# s6064           146.0              NaN             NaN               NaN
# s6136            15.0              NaN             NaN               NaN
# s6209            56.0              NaN             NaN               NaN
# s6247           114.0              NaN             NaN               NaN
# s6249            48.0              NaN             NaN               NaN
#
#             COMBINATIONS CATEGORY ACADEMIC LEVEL CATEGORY  prev_gpa     gpa  \
# school_code
# s0101                       MIXED             COMBINED OA    2.7577  3.0222
# s0103                         NaN                     NaN    2.7099  2.8265
# s0104                         NaN                     NaN    2.7455  2.4112
# s0105                         NaN                     NaN    2.1617  2.3932
# s0106                         NaN                     NaN    2.7917  2.5000
# ...                           ...                     ...       ...     ...
# s6064                         NaN                     NaN    2.8938  3.2005
# s6136                         NaN                     NaN    3.4778  2.4889
# s6209                         NaN                     NaN    2.8244  2.3827
# s6247                         NaN                     NaN    2.3480  2.2991
# s6249                         NaN                     NaN    2.5069  1.9432
#
#                sat  STUDENTS  TEACHERS STUDENT-TEACHER RATIO  \
# school_code
# s0101        158.0    1515.0      80.0                  19:1
# s0103        389.0       NaN       NaN                   NaN
# s0104        122.0       NaN       NaN                   NaN
# s0105        220.0       NaN       NaN                   NaN
# s0106          4.0       NaN       NaN                   NaN
# ...            ...       ...       ...                   ...
# s6064        217.0       NaN       NaN                   NaN
# s6136         15.0       NaN       NaN                   NaN
# s6209         54.0       NaN       NaN                   NaN
# s6247         39.0       NaN       NaN                   NaN
# s6249         88.0       NaN       NaN                   NaN
#
#              student_teacher_ratio  studying_hours  number_of_books  \
# school_code
# s0101                      18.9375       97.132930              660
# s0103                          NaN      108.672330              641
# s0104                          NaN      107.607907              394
# s0105                          NaN       95.476595              467
# s0106                          NaN      102.004858              633
# ...                            ...             ...              ...
# s6064                          NaN      138.150922              727
# s6136                          NaN       81.084489              560
# s6209                          NaN      104.781522              500
# s6247                          NaN       80.561869              699
# s6249                          NaN       59.011366              411
#
#             teacher_qualification
# school_code
# s0101                    Advanced
# s0103                Intermediate
# s0104                Intermediate
# s0105                Intermediate
# s0106                Intermediate
# ...                           ...
# s6064                    Advanced
# s6136                       Basic
# s6209                Intermediate
# s6247                Intermediate
# s6249                       Basic
#
# [858 rows x 16 columns]

# %%
df = df[ ~df.student_teacher_ratio.isnull()]

# %%
df
# Out:
#              prev_sat SCHOOL OWNERSHIP SCHOOL CATEGORY       SCHOOL TYPE  \
# school_code
# s0101           196.0       GOVERNMENT       BOYS ONLY  DAY AND BOARDING
# s0108           280.0       GOVERNMENT  BOYS AND GIRLS          BOARDING
# s0110           183.0       GOVERNMENT       BOYS ONLY          BOARDING
# s0113            22.0          PRIVATE       BOYS ONLY          BOARDING
# s0119           183.0       GOVERNMENT       BOYS ONLY          BOARDING
# ...               ...              ...             ...               ...
# s5145           211.0       GOVERNMENT  BOYS AND GIRLS          BOARDING
# s5164            45.0          PRIVATE  BOYS AND GIRLS  DAY AND BOARDING
# s5184            52.0          PRIVATE  BOYS AND GIRLS          BOARDING
# s5377            12.0          PRIVATE  BOYS AND GIRLS  DAY AND BOARDING
# s5379            52.0          PRIVATE  BOYS AND GIRLS  DAY AND BOARDING
#
#             COMBINATIONS CATEGORY ACADEMIC LEVEL CATEGORY  prev_gpa     gpa  \
# school_code
# s0101                       MIXED             COMBINED OA    2.7577  3.0222
# s0108                     SCIENCE             COMBINED OA    2.7375  2.7662
# s0110                       MIXED             COMBINED OA    1.6548  1.5956
# s0113                       MIXED             COMBINED OA    2.7576  2.7544
# s0119                       MIXED             COMBINED OA    1.6384  1.4167
# ...                           ...                     ...       ...     ...
# s5145                     SCIENCE             ALEVEL ONLY    3.2678  2.7089
# s5164                        ARTS             COMBINED OA    2.2074  1.9125
# s5184                       MIXED             COMBINED OA    2.2628  2.5497
# s5377                         NaN                     NaN    2.6806  3.1667
# s5379                         NaN                     NaN    1.8173  1.9483
#
#                sat  STUDENTS  TEACHERS STUDENT-TEACHER RATIO  \
# school_code
# s0101        158.0    1515.0      80.0                  19:1
# s0108        390.0    1000.0      80.0                  13:1
# s0110        163.0     730.0      60.0                  12:1
# s0113         19.0     300.0      30.0                  10:1
# s0119        162.0     820.0      70.0                  12:1
# ...            ...       ...       ...                   ...
# s5145        241.0     800.0      40.0                  20:1
# s5164         40.0     450.0      35.0                  13:1
# s5184        104.0     600.0      45.0                  13:1
# s5377          5.0     400.0      30.0                  13:1
# s5379         29.0     210.0      20.0                  11:1
#
#              student_teacher_ratio  studying_hours  number_of_books  \
# school_code
# s0101                    18.937500       97.132930              660
# s0108                    12.500000      121.301963              448
# s0110                    12.166667       87.378520              253
# s0113                    10.000000       94.148485              497
# s0119                    11.714286        7.804424              291
# ...                            ...             ...              ...
# s5145                    20.000000      115.627288              459
# s5164                    12.857143      101.652918              271
# s5184                    13.333333       78.455173              517
# s5377                    13.333333      134.579086              657
# s5379                    10.500000      107.965375              466
#
#             teacher_qualification
# school_code
# s0101                    Advanced
# s0108                Intermediate
# s0110                       Basic
# s0113                Intermediate
# s0119                       Basic
# ...                           ...
# s5145                Intermediate
# s5164                    Advanced
# s5184                       Basic
# s5377                    Advanced
# s5379                       Basic
#
# [178 rows x 16 columns]

# %%
df.to_csv('data/df_.csv')

# %%
df.describe()
# Out:
#          prev_sat    prev_gpa         gpa         sat     STUDENTS  \
# count  178.000000  177.000000  178.000000  178.000000   178.000000
# mean   113.084270    2.560664    2.456174  117.404494   661.123596
# std    126.447232    0.497044    0.470863  129.341725   433.651252
# min      1.000000    1.289100    1.365700    2.000000   144.000000
# 25%     29.250000    2.244400    2.136675   31.000000   400.000000
# 50%     63.000000    2.618800    2.404600   73.500000   545.000000
# 75%    142.250000    2.853700    2.760550  147.750000   800.000000
# max    676.000000    3.654600    3.738100  585.000000  3500.000000
#
#          TEACHERS  student_teacher_ratio  studying_hours  number_of_books
# count  178.000000             178.000000      178.000000       178.000000
# mean    40.022472              16.451816       99.314844       538.702247
# std     19.455572               5.631726       27.599192       132.094283
# min     10.000000               8.947368        7.804424        40.000000
# 25%     30.000000              12.500000       79.837082       460.250000
# 50%     35.000000              15.058140       99.351690       532.500000
# 75%     50.000000              19.933333      117.747282       616.750000
# max    115.000000              41.860465      166.325219       877.000000

# %%
Q1 = df['student_teacher_ratio'].quantile(0.25)
Q3 = df['student_teacher_ratio'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['student_teacher_ratio'] < lower_bound) | (df['student_teacher_ratio'] > upper_bound)]

# %%
outliers
# Out:
#              prev_sat SCHOOL OWNERSHIP SCHOOL CATEGORY       SCHOOL TYPE  \
# school_code
# s0443           107.0          PRIVATE  BOYS AND GIRLS  DAY AND BOARDING
# s0551           171.0       GOVERNMENT  BOYS AND GIRLS               NaN
# s0681           199.0          PRIVATE  BOYS AND GIRLS          BOARDING
# s0713           144.0       GOVERNMENT  BOYS AND GIRLS  DAY AND BOARDING
# s1278           220.0          PRIVATE  BOYS AND GIRLS  DAY AND BOARDING
# s3914           389.0          PRIVATE  BOYS AND GIRLS          BOARDING
#
#             COMBINATIONS CATEGORY ACADEMIC LEVEL CATEGORY  prev_gpa     gpa  \
# school_code
# s0443                       MIXED             COMBINED OA    2.5967  2.5725
# s0551                        ARTS             COMBINED OA    1.8158  1.6872
# s0681                        ARTS             COMBINED OA    2.2253  1.9127
# s0713                        ARTS             COMBINED OA    1.6725  1.7516
# s1278                       MIXED             COMBINED OA    2.4250  2.3082
# s3914                       MIXED             COMBINED OA    2.9737  3.0131
#
#                sat  STUDENTS  TEACHERS STUDENT-TEACHER RATIO  \
# school_code
# s0443         36.0    2650.0      75.0                   0:1
# s0551        154.0    1117.0      32.0                  35:1
# s0681        190.0    1800.0      43.0                  42:1
# s0713        104.0     750.0      24.0                  31:1
# s1278        147.0    1000.0      30.0                  33:1
# s3914        297.0    3500.0     100.0                  35:1
#
#              student_teacher_ratio  studying_hours  number_of_books  \
# school_code
# s0443                    35.333333       24.169071              510
# s0551                    34.906250      128.642488              505
# s0681                    41.860465        2.694734              594
# s0713                    31.250000      167.603526              449
# s1278                    33.333333      184.633847              668
# s3914                    35.000000      167.500127              572
#
#             teacher_qualification
# school_code
# s0443                Intermediate
# s0551                       Basic
# s0681                Intermediate
# s0713                       Basic
# s1278                Intermediate
# s3914                    Advanced

# %%
Q1 = df['STUDENTS'].quantile(0.25)
Q3 = df['STUDENTS'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['STUDENTS'] < lower_bound) | (df['STUDENTS'] > upper_bound)]

# %%
outliers
# Out:
#              prev_sat SCHOOL OWNERSHIP SCHOOL CATEGORY       SCHOOL TYPE  \
# school_code
# s0101           196.0       GOVERNMENT       BOYS ONLY  DAY AND BOARDING
# s0333           370.0       GOVERNMENT  BOYS AND GIRLS  DAY AND BOARDING
# s0345           187.0       GOVERNMENT  BOYS AND GIRLS  DAY AND BOARDING
# s0443           107.0          PRIVATE  BOYS AND GIRLS  DAY AND BOARDING
# s0534            80.0          PRIVATE  BOYS AND GIRLS          BOARDING
# s0681           199.0          PRIVATE  BOYS AND GIRLS          BOARDING
# s0731            71.0          PRIVATE  BOYS AND GIRLS  DAY AND BOARDING
# s0960           412.0       GOVERNMENT  BOYS AND GIRLS               DAY
# s1141             2.0          PRIVATE  BOYS AND GIRLS          BOARDING
# s3914           389.0          PRIVATE  BOYS AND GIRLS          BOARDING
#
#             COMBINATIONS CATEGORY ACADEMIC LEVEL CATEGORY  prev_gpa     gpa  \
# school_code
# s0101                       MIXED             COMBINED OA    2.7577  3.0222
# s0333                       MIXED             COMBINED OA    2.7766  2.3345
# s0345                       MIXED             COMBINED OA    3.3877  2.5053
# s0443                       MIXED             COMBINED OA    2.5967  2.5725
# s0534                       MIXED             COMBINED OA    2.6854  2.6337
# s0681                        ARTS             COMBINED OA    2.2253  1.9127
# s0731                       MIXED             COMBINED OA    2.1549  2.3476
# s0960                       MIXED             COMBINED OA    3.1545  3.1348
# s1141                       MIXED             COMBINED OA    2.6667  1.7500
# s3914                       MIXED             COMBINED OA    2.9737  3.0131
#
#                sat  STUDENTS  TEACHERS STUDENT-TEACHER RATIO  \
# school_code
# s0101        158.0    1515.0      80.0                  19:1
# s0333        429.0    2000.0     100.0                  20:1
# s0345        189.0    1480.0      75.0                  20:1
# s0443         36.0    2650.0      75.0                   0:1
# s0534         81.0    1600.0      76.0                  21:1
# s0681        190.0    1800.0      43.0                  42:1
# s0731         82.0    1826.0     115.0                  16:1
# s0960        403.0    1800.0      90.0                  20:1
# s1141          2.0    1500.0     110.0                  14:1
# s3914        297.0    3500.0     100.0                  35:1
#
#              student_teacher_ratio  studying_hours  number_of_books  \
# school_code
# s0101                    18.937500      124.154289              500
# s0333                    20.000000      101.359407              500
# s0345                    19.733333      112.687474              500
# s0443                    35.333333       85.948590              500
# s0534                    21.052632      103.859268              500
# s0681                    41.860465       82.723016              500
# s0731                    15.878261       89.083228              500
# s0960                    20.000000      119.551514              500
# s1141                    13.636364       74.822312              500
# s3914                    35.000000      120.738941              500
#
#             teacher_qualification
# school_code
# s0101                       Basic
# s0333                Intermediate
# s0345                    Advanced
# s0443                    Advanced
# s0534                    Advanced
# s0681                       Basic
# s0731                Intermediate
# s0960                    Advanced
# s1141                    Advanced
# s3914                    Advanced

# %%
Q1 = df['TEACHERS'].quantile(0.25)
Q3 = df['TEACHERS'].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = df[(df['TEACHERS'] < lower_bound) | (df['TEACHERS'] > upper_bound)]

# %%
outliers
# Out:
#              prev_sat SCHOOL OWNERSHIP SCHOOL CATEGORY       SCHOOL TYPE  \
# school_code
# s0333           370.0       GOVERNMENT  BOYS AND GIRLS  DAY AND BOARDING
# s0578            78.0          PRIVATE  BOYS AND GIRLS               DAY
# s0731            71.0          PRIVATE  BOYS AND GIRLS  DAY AND BOARDING
# s0960           412.0       GOVERNMENT  BOYS AND GIRLS               DAY
# s1141             2.0          PRIVATE  BOYS AND GIRLS          BOARDING
# s3914           389.0          PRIVATE  BOYS AND GIRLS          BOARDING
#
#             COMBINATIONS CATEGORY ACADEMIC LEVEL CATEGORY  prev_gpa     gpa  \
# school_code
# s0333                       MIXED             COMBINED OA    2.7766  2.3345
# s0578                       MIXED             COMBINED OA    2.8537  2.9797
# s0731                       MIXED             COMBINED OA    2.1549  2.3476
# s0960                       MIXED             COMBINED OA    3.1545  3.1348
# s1141                       MIXED             COMBINED OA    2.6667  1.7500
# s3914                       MIXED             COMBINED OA    2.9737  3.0131
#
#                sat  STUDENTS  TEACHERS STUDENT-TEACHER RATIO  \
# school_code
# s0333        429.0    2000.0     100.0                  20:1
# s0578         83.0    1060.0      90.0                  12:1
# s0731         82.0    1826.0     115.0                  16:1
# s0960        403.0    1800.0      90.0                  20:1
# s1141          2.0    1500.0     110.0                  14:1
# s3914        297.0    3500.0     100.0                  35:1
#
#              student_teacher_ratio  studying_hours  number_of_books  \
# school_code
# s0333                    20.000000      101.359407              500
# s0578                    11.777778      109.529322              500
# s0731                    15.878261       89.083228              500
# s0960                    20.000000      119.551514              500
# s1141                    13.636364       74.822312              500
# s3914                    35.000000      120.738941              500
#
#             teacher_qualification
# school_code
# s0333                Intermediate
# s0578                Intermediate
# s0731                Intermediate
# s0960                    Advanced
# s1141                    Advanced
# s3914                    Advanced
